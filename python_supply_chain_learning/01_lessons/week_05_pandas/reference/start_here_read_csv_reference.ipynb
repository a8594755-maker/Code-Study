# %% [markdown]
# # Start Here: Read CSV with pandas
#
# 這份 notebook 只做第一件事：像分析師一樣把 CSV 讀進來，然後先看資料。

# %% [markdown]
# ## 1. 載入 pandas
#
# 人類思路：我要使用 pandas 這個工具處理表格資料。

# %%
import pandas as pd

# %% [markdown]
# ## 2. 指定 CSV 檔案位置
#
# 人類思路：我要先告訴 Python 這份資料在哪裡。

# %%
from pathlib import Path

data_file = Path("/Users/xuweijin/Code study/python_supply_chain_learning/03_data/superstore.csv")

data_file.exists()

# %% [markdown]
# 如果上一格顯示 `True`，代表 CSV 檔案找到了。

# %% [markdown]
# ## 3. 讀 CSV
#
# 人類思路：我要把 CSV 讀成一張 pandas DataFrame。

# %%
df = pd.read_csv(data_file)

# %% [markdown]
# ## 4. 看前 5 筆資料
#
# 人類思路：資料讀進來後，我先看它長什麼樣。

# %%
df.head()

# %% [markdown]
# ## 5. 看資料大小
#
# 人類思路：我要知道這份資料有幾列、幾欄。

# %%
df.shape

# %% [markdown]
# ## 6. 看欄位名稱
#
# 人類思路：欄位名稱決定我可以問哪些分析問題。

# %%
df.columns.tolist()
